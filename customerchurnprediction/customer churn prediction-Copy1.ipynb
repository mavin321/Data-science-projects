# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#reading the dataset

# %%
df=pd.read_csv('tested.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
#handling missing data

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
df['Fare'] = pd.to_numeric(df['Fare'], errors='coerce')

age_median = df['Age'].median()
fare_median = df['Fare'].median()

df.fillna({'Age': age_median, 'Cabin': 'N/A', 'Fare': fare_median}, inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#visualizing the data

# %%
sns.barplot(x='Sex', y='Survived', data=df)
plt.title("sex vs survived")
plt.show()

# %%
sns.histplot(data=df, x='Age',bins=30, kde=True)
plt.title("Age Distribution of Passengers")
plt.show()

# %%
df.head(155)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 150         1042         1       1
# 151         1043         0       3
# 152         1044         0       3
# 153         1045         1       3
# 154         1046         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 0                                  Kelly, Mr. James    male  34.5      0
# 1                  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                         Myles, Mr. Thomas Francis    male  62.0      0
# 3                                  Wirz, Mr. Albert    male  27.0      0
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                              ...     ...   ...    ...
# 150           Earnshaw, Mrs. Boulton (Olive Potter)  female  23.0      0
# 151                            Matinoff, Mr. Nicola    male  27.0      0
# 152                              Storey, Mr. Thomas    male  60.5      0
# 153  Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)  female  36.0      0
# 154                    Asplund, Master. Filip Oscar    male  13.0      4
#
#      Parch   Ticket     Fare Cabin Embarked
# 0        0   330911   7.8292   N/A        Q
# 1        0   363272   7.0000   N/A        S
# 2        0   240276   9.6875   N/A        Q
# 3        0   315154   8.6625   N/A        S
# 4        1  3101298  12.2875   N/A        S
# ..     ...      ...      ...   ...      ...
# 150      1    11767  83.1583   C54        C
# 151      0   349255   7.8958   N/A        C
# 152      0     3701  14.4542   N/A        S
# 153      2   350405  12.1833   N/A        S
# 154      2   347077  31.3875   N/A        S
#
# [155 rows x 12 columns]

# %%
survival_by_class = df.groupby("Pclass")["Survived"].mean()
print(survival_by_class)
# Out:
# Pclass
# 1    0.467290
# 2    0.322581
# 3    0.330275
# Name: Survived, dtype: float64
